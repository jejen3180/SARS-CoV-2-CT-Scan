# %%
import numpy as np
import pandas as pd
import os
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from keras.layers import Dense, Conv2D, BatchNormalization, GlobalAveragePooling2D, Input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical

# Set seed for reproducibility
Seed = 40
np.random.seed(Seed)

data_dir = '../Data/sarscov2-ctscan-dataset'

# Load and preprocess data
disease_types = ['COVID', 'non-COVID']

train_data = []

for index, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(data_dir, sp)):
        train_data.append([sp + "/" + file, index, sp])

train = pd.DataFrame(train_data, columns=['File', 'ID', 'Disease Type'])

# Reset indices (row numbers)
train = train.sample(frac=1, replace=False, random_state=Seed)
train = train.reset_index(drop=True)

# Assuming you have defined IMAGE_SIZE and channels
IMAGE_SIZE = 224
channels = 3

# OpenCV Function to load colored image
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath))

# OpenCV Function to resize an image
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))

for i, file in enumerate(train['File'].values):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))

X_train = X_train / 255.0  # Pixel normalization

Y_train = to_categorical(train['ID'].values, num_classes=2)

# Split the data into training and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=Seed)

# Function to build InceptionV3 model
def build_inceptionv3(IMAGE_SIZE, channels):
    inceptionv3 = InceptionV3(weights='imagenet', include_top=False)
    input = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, channels))
    x = Conv2D(3, (3, 3), padding='same')(input)
    x = inceptionv3(x)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    output = Dense(2, activation='softmax')(x)

    model = Model(input, output)

    initial_learning_rate = 0.003
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate,
        decay_steps=100000,  # Adjust this value as needed
        decay_rate=0.96,
        staircase=True)

    optimizer = Adam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=0.1)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

# Build three separate InceptionV3 models
model1 = build_inceptionv3(IMAGE_SIZE, channels)
model2 = build_inceptionv3(IMAGE_SIZE, channels)
model3 = build_inceptionv3(IMAGE_SIZE, channels)

# Data augmentation
datagen = ImageDataGenerator(rotation_range=360, width_shift_range=0.2, height_shift_range=0.2,
                             zoom_range=0.2, horizontal_flip=True, vertical_flip=True)
datagen.fit(X_train)

# Train each model separately
models = [model1, model2, model3]
for i, model in enumerate(models):
    print(f"\nTraining Model {i + 1}")
    hist = model.fit(datagen.flow(X_train, Y_train, batch_size=32),
                     steps_per_epoch=X_train.shape[0] // 32,
                     epochs=75,  # Adjust the number of epochs as needed
                     verbose=1)

# Ensemble model by averaging predictions
def ensemble_predict(models, X_val):
    predictions = [model.predict(X_val) for model in models]
    ensemble_pred = np.mean(predictions, axis=0)
    return ensemble_pred

# Evaluate the ensemble model
ensemble_predictions = ensemble_predict(models, X_val)
ensemble_predictions = np.argmax(ensemble_predictions, axis=1)
Y_true = np.argmax(Y_val, axis=1)

ensemble_cm = confusion_matrix(Y_true, ensemble_predictions)
plt.figure(figsize=(12, 12))
ax = sns.heatmap(ensemble_cm, cmap=plt.cm.Greens, annot=True, square=True, xticklabels=disease_types, yticklabels=disease_types)
ax.set_ylabel('Actual', fontsize=40)
ax.set_xlabel('Predicted', fontsize=40)

# Calculate and print metrics
ensemble_TP = ensemble_cm[1][1]
ensemble_FN = ensemble_cm[1][0]
ensemble_TN = ensemble_cm[0][0]
ensemble_FP = ensemble_cm[0][1]

print(f"Ensemble True Positive: {ensemble_TP}")
print(f"Ensemble False Negative: {ensemble_FN}")
print(f"Ensemble True Negative: {ensemble_TN}")
print(f"Ensemble False Positive: {ensemble_FP}")
print(f"Ensemble True Positive Rate: {ensemble_TP / (ensemble_TP + ensemble_FN)}")
print(f"Ensemble True Negative Rate: {ensemble_TN / (ensemble_TN + ensemble_FP)}")
# Out:
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 19s 0us/step
#
# Training Model 1
# Epoch 1/75
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 62/62 [==============================] - 491s 6s/step - loss: 0.6597 - accuracy: 0.6714
# Epoch 2/75
# 62/62 [==============================] - 354s 6s/step - loss: 0.4392 - accuracy: 0.8059
# Epoch 3/75
# 62/62 [==============================] - 364s 6s/step - loss: 0.3995 - accuracy: 0.8387
# Epoch 4/75
# 62/62 [==============================] - 357s 6s/step - loss: 0.3847 - accuracy: 0.8362
# Epoch 5/75
# 62/62 [==============================] - 343s 5s/step - loss: 0.3384 - accuracy: 0.8528
# Epoch 6/75
# 62/62 [==============================] - 362s 6s/step - loss: 0.3229 - accuracy: 0.8564
# Epoch 7/75
# 62/62 [==============================] - 352s 6s/step - loss: 0.2753 - accuracy: 0.8790
# Epoch 8/75
# 62/62 [==============================] - 344s 6s/step - loss: 0.2625 - accuracy: 0.8866
# Epoch 9/75
# 62/62 [==============================] - 349s 6s/step - loss: 0.2421 - accuracy: 0.8896
# Epoch 10/75
# 62/62 [==============================] - 358s 6s/step - loss: 0.2172 - accuracy: 0.9032
# Epoch 11/75
# 62/62 [==============================] - 373s 6s/step - loss: 0.1909 - accuracy: 0.9214
# Epoch 12/75
# 62/62 [==============================] - 358s 6s/step - loss: 0.1738 - accuracy: 0.9294
# Epoch 13/75
# 62/62 [==============================] - 344s 6s/step - loss: 0.1692 - accuracy: 0.9320
# Epoch 14/75
# 62/62 [==============================] - 374s 6s/step - loss: 0.1523 - accuracy: 0.9410
# Epoch 15/75
# 62/62 [==============================] - 384s 6s/step - loss: 0.1451 - accuracy: 0.9415
# Epoch 16/75
# 62/62 [==============================] - 372s 6s/step - loss: 0.1508 - accuracy: 0.9466
# Epoch 17/75
# 62/62 [==============================] - 383s 6s/step - loss: 0.1416 - accuracy: 0.9481
# Epoch 18/75
# 62/62 [==============================] - 361s 6s/step - loss: 0.1449 - accuracy: 0.9390
# Epoch 19/75
# 62/62 [==============================] - 379s 6s/step - loss: 0.1342 - accuracy: 0.9506
# Epoch 20/75
# 62/62 [==============================] - 373s 6s/step - loss: 0.1162 - accuracy: 0.9551
# Epoch 21/75
# 62/62 [==============================] - 404s 6s/step - loss: 0.1055 - accuracy: 0.9617
# Epoch 22/75
# 62/62 [==============================] - 406s 7s/step - loss: 0.1214 - accuracy: 0.9481
# Epoch 23/75
# 62/62 [==============================] - 429s 7s/step - loss: 0.1101 - accuracy: 0.9592
# Epoch 24/75
# 62/62 [==============================] - 399s 6s/step - loss: 0.1127 - accuracy: 0.9526
# Epoch 25/75
# 62/62 [==============================] - 305s 5s/step - loss: 0.1014 - accuracy: 0.9592
# Epoch 26/75
# 62/62 [==============================] - 279s 4s/step - loss: 0.0973 - accuracy: 0.9632
# Epoch 27/75
# 62/62 [==============================] - 330s 5s/step - loss: 0.0928 - accuracy: 0.9657
# Epoch 28/75
# 62/62 [==============================] - 335s 5s/step - loss: 0.0976 - accuracy: 0.9622
# Epoch 29/75
# 62/62 [==============================] - 313s 5s/step - loss: 0.0734 - accuracy: 0.9713
# Epoch 30/75
# 62/62 [==============================] - 304s 5s/step - loss: 0.0848 - accuracy: 0.9667
# Epoch 31/75
# 62/62 [==============================] - 314s 5s/step - loss: 0.0653 - accuracy: 0.9773
# Epoch 32/75
# 62/62 [==============================] - 298s 5s/step - loss: 0.0792 - accuracy: 0.9703
# Epoch 33/75
# 62/62 [==============================] - 309s 5s/step - loss: 0.0619 - accuracy: 0.9783
# Epoch 34/75
# 62/62 [==============================] - 313s 5s/step - loss: 0.0864 - accuracy: 0.9677
# Epoch 35/75
# 62/62 [==============================] - 315s 5s/step - loss: 0.0664 - accuracy: 0.9743
# Epoch 36/75
# 62/62 [==============================] - 307s 5s/step - loss: 0.0673 - accuracy: 0.9763
# Epoch 37/75
# 62/62 [==============================] - 315s 5s/step - loss: 0.0546 - accuracy: 0.9803
# Epoch 38/75
# 62/62 [==============================] - 308s 5s/step - loss: 0.0523 - accuracy: 0.9803
# Epoch 39/75
# 62/62 [==============================] - 278s 4s/step - loss: 0.0645 - accuracy: 0.9773
# Epoch 40/75
# 62/62 [==============================] - 293s 5s/step - loss: 0.0434 - accuracy: 0.9859
# Epoch 41/75
# 62/62 [==============================] - 311s 5s/step - loss: 0.0602 - accuracy: 0.9743
# Epoch 42/75
# 62/62 [==============================] - 305s 5s/step - loss: 0.0502 - accuracy: 0.9814
# Epoch 43/75
# 62/62 [==============================] - 295s 5s/step - loss: 0.0479 - accuracy: 0.9859
# Epoch 44/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.0534 - accuracy: 0.9814
# Epoch 45/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0365 - accuracy: 0.9864
# Epoch 46/75
# 62/62 [==============================] - 280s 5s/step - loss: 0.0423 - accuracy: 0.9864
# Epoch 47/75
# 62/62 [==============================] - 269s 4s/step - loss: 0.0380 - accuracy: 0.9839
# Epoch 48/75
# 62/62 [==============================] - 276s 4s/step - loss: 0.0593 - accuracy: 0.9748
# Epoch 49/75
# 62/62 [==============================] - 282s 5s/step - loss: 0.0479 - accuracy: 0.9854
# Epoch 50/75
# 62/62 [==============================] - 293s 5s/step - loss: 0.0281 - accuracy: 0.9909
# Epoch 51/75
# 62/62 [==============================] - 278s 4s/step - loss: 0.0403 - accuracy: 0.9854
# Epoch 52/75
# 62/62 [==============================] - 293s 5s/step - loss: 0.0356 - accuracy: 0.9899
# Epoch 53/75
# 62/62 [==============================] - 268s 4s/step - loss: 0.0303 - accuracy: 0.9874
# Epoch 54/75
# 62/62 [==============================] - 272s 4s/step - loss: 0.0357 - accuracy: 0.9879
# Epoch 55/75
# 62/62 [==============================] - 281s 5s/step - loss: 0.0326 - accuracy: 0.9899
# Epoch 56/75
# 62/62 [==============================] - 281s 5s/step - loss: 0.0320 - accuracy: 0.9899
# Epoch 57/75
# 62/62 [==============================] - 280s 4s/step - loss: 0.0301 - accuracy: 0.9884
# Epoch 58/75
# 62/62 [==============================] - 279s 4s/step - loss: 0.0348 - accuracy: 0.9884
# Epoch 59/75
# 62/62 [==============================] - 285s 5s/step - loss: 0.0210 - accuracy: 0.9929
# Epoch 60/75
# 62/62 [==============================] - 286s 5s/step - loss: 0.0363 - accuracy: 0.9869
# Epoch 61/75
# 62/62 [==============================] - 288s 5s/step - loss: 0.0573 - accuracy: 0.9783
# Epoch 62/75
# 62/62 [==============================] - 280s 4s/step - loss: 0.0323 - accuracy: 0.9859
# Epoch 63/75
# 62/62 [==============================] - 294s 5s/step - loss: 0.0338 - accuracy: 0.9874
# Epoch 64/75
# 62/62 [==============================] - 285s 5s/step - loss: 0.0345 - accuracy: 0.9874
# Epoch 65/75
# 62/62 [==============================] - 281s 5s/step - loss: 0.0345 - accuracy: 0.9879
# Epoch 66/75
# 62/62 [==============================] - 296s 5s/step - loss: 0.0266 - accuracy: 0.9929
# Epoch 67/75
# 62/62 [==============================] - 277s 4s/step - loss: 0.0218 - accuracy: 0.9919
# Epoch 68/75
# 62/62 [==============================] - 284s 5s/step - loss: 0.0245 - accuracy: 0.9909
# Epoch 69/75
# 62/62 [==============================] - 283s 5s/step - loss: 0.0244 - accuracy: 0.9904
# Epoch 70/75
# 62/62 [==============================] - 286s 5s/step - loss: 0.0317 - accuracy: 0.9869
# Epoch 71/75
# 62/62 [==============================] - 296s 5s/step - loss: 0.0202 - accuracy: 0.9940
# Epoch 72/75
# 62/62 [==============================] - 295s 5s/step - loss: 0.0142 - accuracy: 0.9955
# Epoch 73/75
# 62/62 [==============================] - 272s 4s/step - loss: 0.0240 - accuracy: 0.9904
# Epoch 74/75
# 62/62 [==============================] - 270s 4s/step - loss: 0.0220 - accuracy: 0.9934
# Epoch 75/75
# 62/62 [==============================] - 276s 4s/step - loss: 0.0273 - accuracy: 0.9904
#
# Training Model 2
# Epoch 1/75
# 62/62 [==============================] - 358s 5s/step - loss: 0.6884 - accuracy: 0.6840
# Epoch 2/75
# 62/62 [==============================] - 275s 4s/step - loss: 0.4475 - accuracy: 0.8065
# Epoch 3/75
# 62/62 [==============================] - 291s 5s/step - loss: 0.3920 - accuracy: 0.8352
# Epoch 4/75
# 62/62 [==============================] - 289s 5s/step - loss: 0.3261 - accuracy: 0.8604
# Epoch 5/75
# 62/62 [==============================] - 278s 4s/step - loss: 0.2985 - accuracy: 0.8795
# Epoch 6/75
# 62/62 [==============================] - 280s 5s/step - loss: 0.2595 - accuracy: 0.8931
# Epoch 7/75
# 62/62 [==============================] - 299s 5s/step - loss: 0.2461 - accuracy: 0.8962
# Epoch 8/75
# 62/62 [==============================] - 278s 4s/step - loss: 0.2265 - accuracy: 0.9083
# Epoch 9/75
# 62/62 [==============================] - 284s 5s/step - loss: 0.2126 - accuracy: 0.9153
# Epoch 10/75
# 62/62 [==============================] - 282s 5s/step - loss: 0.2060 - accuracy: 0.9183
# Epoch 11/75
# 62/62 [==============================] - 275s 4s/step - loss: 0.1715 - accuracy: 0.9320
# Epoch 12/75
# 62/62 [==============================] - 287s 5s/step - loss: 0.1675 - accuracy: 0.9325
# Epoch 13/75
# 62/62 [==============================] - 283s 5s/step - loss: 0.1578 - accuracy: 0.9365
# Epoch 14/75
# 62/62 [==============================] - 286s 5s/step - loss: 0.1495 - accuracy: 0.9420
# Epoch 15/75
# 62/62 [==============================] - 287s 5s/step - loss: 0.1469 - accuracy: 0.9410
# Epoch 16/75
# 62/62 [==============================] - 284s 5s/step - loss: 0.1204 - accuracy: 0.9531
# Epoch 17/75
# 62/62 [==============================] - 291s 5s/step - loss: 0.1229 - accuracy: 0.9561
# Epoch 18/75
# 62/62 [==============================] - 289s 5s/step - loss: 0.1064 - accuracy: 0.9531
# Epoch 19/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.1022 - accuracy: 0.9587
# Epoch 20/75
# 62/62 [==============================] - 285s 5s/step - loss: 0.1017 - accuracy: 0.9632
# Epoch 21/75
# 62/62 [==============================] - 277s 4s/step - loss: 0.1245 - accuracy: 0.9582
# Epoch 22/75
# 62/62 [==============================] - 278s 4s/step - loss: 0.1049 - accuracy: 0.9577
# Epoch 23/75
# 62/62 [==============================] - 270s 4s/step - loss: 0.0952 - accuracy: 0.9632
# Epoch 24/75
# 62/62 [==============================] - 270s 4s/step - loss: 0.0872 - accuracy: 0.9682
# Epoch 25/75
# 62/62 [==============================] - 269s 4s/step - loss: 0.0984 - accuracy: 0.9632
# Epoch 26/75
# 62/62 [==============================] - 264s 4s/step - loss: 0.0830 - accuracy: 0.9723
# Epoch 27/75
# 62/62 [==============================] - 275s 4s/step - loss: 0.0941 - accuracy: 0.9657
# Epoch 28/75
# 62/62 [==============================] - 276s 4s/step - loss: 0.0794 - accuracy: 0.9677
# Epoch 29/75
# 62/62 [==============================] - 317s 5s/step - loss: 0.0816 - accuracy: 0.9703
# Epoch 30/75
# 62/62 [==============================] - 281s 5s/step - loss: 0.0783 - accuracy: 0.9748
# Epoch 31/75
# 62/62 [==============================] - 317s 5s/step - loss: 0.0645 - accuracy: 0.9758
# Epoch 32/75
# 62/62 [==============================] - 321s 5s/step - loss: 0.0620 - accuracy: 0.9768
# Epoch 33/75
# 62/62 [==============================] - 323s 5s/step - loss: 0.0657 - accuracy: 0.9758
# Epoch 34/75
# 62/62 [==============================] - 324s 5s/step - loss: 0.0445 - accuracy: 0.9844
# Epoch 35/75
# 62/62 [==============================] - 311s 5s/step - loss: 0.0614 - accuracy: 0.9773
# Epoch 36/75
# 62/62 [==============================] - 306s 5s/step - loss: 0.0619 - accuracy: 0.9788
# Epoch 37/75
# 62/62 [==============================] - 314s 5s/step - loss: 0.0500 - accuracy: 0.9829
# Epoch 38/75
# 62/62 [==============================] - 327s 5s/step - loss: 0.0612 - accuracy: 0.9788
# Epoch 39/75
# 62/62 [==============================] - 319s 5s/step - loss: 0.0439 - accuracy: 0.9824
# Epoch 40/75
# 62/62 [==============================] - 315s 5s/step - loss: 0.0571 - accuracy: 0.9773
# Epoch 41/75
# 62/62 [==============================] - 318s 5s/step - loss: 0.0280 - accuracy: 0.9904
# Epoch 42/75
# 62/62 [==============================] - 326s 5s/step - loss: 0.0328 - accuracy: 0.9884
# Epoch 43/75
# 62/62 [==============================] - 322s 5s/step - loss: 0.0469 - accuracy: 0.9814
# Epoch 44/75
# 62/62 [==============================] - 317s 5s/step - loss: 0.0446 - accuracy: 0.9839
# Epoch 45/75
# 62/62 [==============================] - 323s 5s/step - loss: 0.0474 - accuracy: 0.9829
# Epoch 46/75
# 62/62 [==============================] - 317s 5s/step - loss: 0.0542 - accuracy: 0.9793
# Epoch 47/75
# 62/62 [==============================] - 312s 5s/step - loss: 0.0450 - accuracy: 0.9839
# Epoch 48/75
# 62/62 [==============================] - 313s 5s/step - loss: 0.0435 - accuracy: 0.9824
# Epoch 49/75
# 62/62 [==============================] - 306s 5s/step - loss: 0.0379 - accuracy: 0.9879
# Epoch 50/75
# 62/62 [==============================] - 314s 5s/step - loss: 0.0429 - accuracy: 0.9854
# Epoch 51/75
# 62/62 [==============================] - 311s 5s/step - loss: 0.0442 - accuracy: 0.9839
# Epoch 52/75
# 62/62 [==============================] - 312s 5s/step - loss: 0.0280 - accuracy: 0.9904
# Epoch 53/75
# 62/62 [==============================] - 318s 5s/step - loss: 0.0311 - accuracy: 0.9899
# Epoch 54/75
# 62/62 [==============================] - 307s 5s/step - loss: 0.0389 - accuracy: 0.9869
# Epoch 55/75
# 62/62 [==============================] - 298s 5s/step - loss: 0.0247 - accuracy: 0.9919
# Epoch 56/75
# 62/62 [==============================] - 310s 5s/step - loss: 0.0275 - accuracy: 0.9894
# Epoch 57/75
# 62/62 [==============================] - 315s 5s/step - loss: 0.0291 - accuracy: 0.9899
# Epoch 58/75
# 62/62 [==============================] - 321s 5s/step - loss: 0.0272 - accuracy: 0.9919
# Epoch 59/75
# 62/62 [==============================] - 293s 5s/step - loss: 0.0262 - accuracy: 0.9889
# Epoch 60/75
# 62/62 [==============================] - 378s 6s/step - loss: 0.0211 - accuracy: 0.9945
# Epoch 61/75
# 62/62 [==============================] - 361s 6s/step - loss: 0.0358 - accuracy: 0.9874
# Epoch 62/75
# 62/62 [==============================] - 405s 6s/step - loss: 0.0180 - accuracy: 0.9924
# Epoch 63/75
# 62/62 [==============================] - 404s 6s/step - loss: 0.0309 - accuracy: 0.9904
# Epoch 64/75
# 62/62 [==============================] - 421s 7s/step - loss: 0.0420 - accuracy: 0.9869
# Epoch 65/75
# 62/62 [==============================] - 401s 6s/step - loss: 0.0283 - accuracy: 0.9904
# Epoch 66/75
# 62/62 [==============================] - 421s 7s/step - loss: 0.0345 - accuracy: 0.9879
# Epoch 67/75
# 62/62 [==============================] - 408s 7s/step - loss: 0.0173 - accuracy: 0.9950
# Epoch 68/75
# 62/62 [==============================] - 374s 6s/step - loss: 0.0225 - accuracy: 0.9914
# Epoch 69/75
# 62/62 [==============================] - 384s 6s/step - loss: 0.0330 - accuracy: 0.9879
# Epoch 70/75
# 62/62 [==============================] - 387s 6s/step - loss: 0.0200 - accuracy: 0.9919
# Epoch 71/75
# 62/62 [==============================] - 389s 6s/step - loss: 0.0269 - accuracy: 0.9904
# Epoch 72/75
# 62/62 [==============================] - 328s 5s/step - loss: 0.0227 - accuracy: 0.9919
# Epoch 73/75
# 62/62 [==============================] - 293s 5s/step - loss: 0.0164 - accuracy: 0.9940
# Epoch 74/75
# 62/62 [==============================] - 244s 4s/step - loss: 0.0211 - accuracy: 0.9924
# Epoch 75/75
# 62/62 [==============================] - 233s 4s/step - loss: 0.0279 - accuracy: 0.9909
#
# Training Model 3
# Epoch 1/75
# 62/62 [==============================] - 287s 4s/step - loss: 0.6421 - accuracy: 0.6830
# Epoch 2/75
# 62/62 [==============================] - 221s 4s/step - loss: 0.4830 - accuracy: 0.7908
# Epoch 3/75
# 62/62 [==============================] - 230s 4s/step - loss: 0.3932 - accuracy: 0.8327
# Epoch 4/75
# 62/62 [==============================] - 232s 4s/step - loss: 0.3484 - accuracy: 0.8523
# Epoch 5/75
# 62/62 [==============================] - 222s 4s/step - loss: 0.3118 - accuracy: 0.8639
# Epoch 6/75
# 62/62 [==============================] - 244s 4s/step - loss: 0.2836 - accuracy: 0.8795
# Epoch 7/75
# 62/62 [==============================] - 234s 4s/step - loss: 0.2453 - accuracy: 0.8977
# Epoch 8/75
# 62/62 [==============================] - 243s 4s/step - loss: 0.2564 - accuracy: 0.8916
# Epoch 9/75
# 62/62 [==============================] - 278s 4s/step - loss: 0.1994 - accuracy: 0.9183
# Epoch 10/75
# 62/62 [==============================] - 277s 4s/step - loss: 0.2154 - accuracy: 0.9057
# Epoch 11/75
# 62/62 [==============================] - 253s 4s/step - loss: 0.1727 - accuracy: 0.9289
# Epoch 12/75
# 62/62 [==============================] - 257s 4s/step - loss: 0.1647 - accuracy: 0.9350
# Epoch 13/75
# 62/62 [==============================] - 270s 4s/step - loss: 0.1569 - accuracy: 0.9365
# Epoch 14/75
# 62/62 [==============================] - 260s 4s/step - loss: 0.1480 - accuracy: 0.9350
# Epoch 15/75
# 62/62 [==============================] - 268s 4s/step - loss: 0.1394 - accuracy: 0.9430
# Epoch 16/75
# 62/62 [==============================] - 265s 4s/step - loss: 0.1725 - accuracy: 0.9299
# Epoch 17/75
# 62/62 [==============================] - 271s 4s/step - loss: 0.1419 - accuracy: 0.9451
# Epoch 18/75
# 62/62 [==============================] - 275s 4s/step - loss: 0.1307 - accuracy: 0.9526
# Epoch 19/75
# 62/62 [==============================] - 283s 5s/step - loss: 0.1041 - accuracy: 0.9582
# Epoch 20/75
# 62/62 [==============================] - 270s 4s/step - loss: 0.1161 - accuracy: 0.9536
# Epoch 21/75
# 62/62 [==============================] - 288s 5s/step - loss: 0.1070 - accuracy: 0.9622
# Epoch 22/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.1181 - accuracy: 0.9546
# Epoch 23/75
# 62/62 [==============================] - 279s 4s/step - loss: 0.0882 - accuracy: 0.9642
# Epoch 24/75
# 62/62 [==============================] - 282s 5s/step - loss: 0.0963 - accuracy: 0.9637
# Epoch 25/75
# 62/62 [==============================] - 276s 4s/step - loss: 0.0945 - accuracy: 0.9677
# Epoch 26/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0819 - accuracy: 0.9708
# Epoch 27/75
# 62/62 [==============================] - 281s 5s/step - loss: 0.0863 - accuracy: 0.9667
# Epoch 28/75
# 62/62 [==============================] - 277s 4s/step - loss: 0.0972 - accuracy: 0.9637
# Epoch 29/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.0720 - accuracy: 0.9698
# Epoch 30/75
# 62/62 [==============================] - 286s 5s/step - loss: 0.0711 - accuracy: 0.9693
# Epoch 31/75
# 62/62 [==============================] - 277s 4s/step - loss: 0.0662 - accuracy: 0.9758
# Epoch 32/75
# 62/62 [==============================] - 272s 4s/step - loss: 0.0791 - accuracy: 0.9718
# Epoch 33/75
# 62/62 [==============================] - 290s 5s/step - loss: 0.0544 - accuracy: 0.9773
# Epoch 34/75
# 62/62 [==============================] - 275s 4s/step - loss: 0.0649 - accuracy: 0.9773
# Epoch 35/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.0712 - accuracy: 0.9768
# Epoch 36/75
# 62/62 [==============================] - 266s 4s/step - loss: 0.0613 - accuracy: 0.9783
# Epoch 37/75
# 62/62 [==============================] - 268s 4s/step - loss: 0.0817 - accuracy: 0.9688
# Epoch 38/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0759 - accuracy: 0.9718
# Epoch 39/75
# 62/62 [==============================] - 268s 4s/step - loss: 0.0586 - accuracy: 0.9778
# Epoch 40/75
# 62/62 [==============================] - 251s 4s/step - loss: 0.0457 - accuracy: 0.9839
# Epoch 41/75
# 62/62 [==============================] - 253s 4s/step - loss: 0.0634 - accuracy: 0.9778
# Epoch 42/75
# 62/62 [==============================] - 241s 4s/step - loss: 0.0511 - accuracy: 0.9824
# Epoch 43/75
# 62/62 [==============================] - 284s 5s/step - loss: 0.0387 - accuracy: 0.9864
# Epoch 44/75
# 62/62 [==============================] - 272s 4s/step - loss: 0.0473 - accuracy: 0.9834
# Epoch 45/75
# 62/62 [==============================] - 272s 4s/step - loss: 0.0462 - accuracy: 0.9808
# Epoch 46/75
# 62/62 [==============================] - 266s 4s/step - loss: 0.0421 - accuracy: 0.9824
# Epoch 47/75
# 62/62 [==============================] - 261s 4s/step - loss: 0.0497 - accuracy: 0.9798
# Epoch 48/75
# 62/62 [==============================] - 270s 4s/step - loss: 0.0587 - accuracy: 0.9758
# Epoch 49/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.0579 - accuracy: 0.9788
# Epoch 50/75
# 62/62 [==============================] - 287s 5s/step - loss: 0.0790 - accuracy: 0.9672
# Epoch 51/75
# 62/62 [==============================] - 272s 4s/step - loss: 0.0557 - accuracy: 0.9793
# Epoch 52/75
# 62/62 [==============================] - 274s 4s/step - loss: 0.0313 - accuracy: 0.9894
# Epoch 53/75
# 62/62 [==============================] - 288s 5s/step - loss: 0.0374 - accuracy: 0.9859
# Epoch 54/75
# 62/62 [==============================] - 284s 5s/step - loss: 0.0385 - accuracy: 0.9869
# Epoch 55/75
# 62/62 [==============================] - 258s 4s/step - loss: 0.0554 - accuracy: 0.9803
# Epoch 56/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0326 - accuracy: 0.9884
# Epoch 57/75
# 62/62 [==============================] - 265s 4s/step - loss: 0.0331 - accuracy: 0.9874
# Epoch 58/75
# 62/62 [==============================] - 261s 4s/step - loss: 0.0413 - accuracy: 0.9839
# Epoch 59/75
# 62/62 [==============================] - 266s 4s/step - loss: 0.0437 - accuracy: 0.9829
# Epoch 60/75
# 62/62 [==============================] - 264s 4s/step - loss: 0.0375 - accuracy: 0.9849
# Epoch 61/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0270 - accuracy: 0.9914
# Epoch 62/75
# 62/62 [==============================] - 299s 5s/step - loss: 0.0317 - accuracy: 0.9879
# Epoch 63/75
# 62/62 [==============================] - 288s 5s/step - loss: 0.0392 - accuracy: 0.9879
# Epoch 64/75
# 62/62 [==============================] - 276s 4s/step - loss: 0.0366 - accuracy: 0.9889
# Epoch 65/75
# 62/62 [==============================] - 269s 4s/step - loss: 0.0385 - accuracy: 0.9849
# Epoch 66/75
# 62/62 [==============================] - 267s 4s/step - loss: 0.0323 - accuracy: 0.9889
# Epoch 67/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0212 - accuracy: 0.9919
# Epoch 68/75
# 62/62 [==============================] - 247s 4s/step - loss: 0.0183 - accuracy: 0.9934
# Epoch 69/75
# 62/62 [==============================] - 258s 4s/step - loss: 0.0241 - accuracy: 0.9919
# Epoch 70/75
# 62/62 [==============================] - 267s 4s/step - loss: 0.0197 - accuracy: 0.9934
# Epoch 71/75
# 62/62 [==============================] - 273s 4s/step - loss: 0.0274 - accuracy: 0.9889
# Epoch 72/75
# 62/62 [==============================] - 280s 4s/step - loss: 0.0253 - accuracy: 0.9904
# Epoch 73/75
# 62/62 [==============================] - 282s 5s/step - loss: 0.0294 - accuracy: 0.9894
# Epoch 74/75
# 62/62 [==============================] - 291s 5s/step - loss: 0.0399 - accuracy: 0.9849
# Epoch 75/75
# 62/62 [==============================] - 286s 5s/step - loss: 0.0307 - accuracy: 0.9909
# 16/16 [==============================] - 20s 916ms/step
# 16/16 [==============================] - 20s 998ms/step
# 16/16 [==============================] - 18s 884ms/step
# Ensemble True Positive: 255
# Ensemble False Negative: 0
# Ensemble True Negative: 230
# Ensemble False Positive: 12
# Ensemble True Positive Rate: 1.0
# Ensemble True Negative Rate: 0.9504132231404959

# %%
from sklearn.metrics import classification_report

# Generate and print the classification report
classification_rep = classification_report(Y_true, ensemble_predictions, target_names=disease_types)
print("Classification Report:\n", classification_rep)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        COVID       1.00      0.95      0.97       242
#    non-COVID       0.96      1.00      0.98       255
#
#     accuracy                           0.98       497
#    macro avg       0.98      0.98      0.98       497
# weighted avg       0.98      0.98      0.98       497

# %%
from sklearn.metrics import confusion_matrix
import scikitplot as skplt
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

sns.set(rc={'figure.figsize':(8,8)})
skplt.metrics.plot_confusion_matrix(Y_true, ensemble_predictions, cmap="BrBG", title="XGBoost")
# Out:
# <Axes: title={'center': 'XGBoost'}, xlabel='Predicted label', ylabel='True label'>

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate and print precision, recall, and F1 score
ensemble_accuracy = accuracy_score(Y_true, ensemble_predictions)
ensemble_precision = precision_score(Y_true, ensemble_predictions)
ensemble_recall = recall_score(Y_true, ensemble_predictions)
ensemble_f1 = f1_score(Y_true, ensemble_predictions)

print(f"Ensemble Accuracy: {ensemble_accuracy}")
print(f"Ensemble Precision: {ensemble_precision}")
print(f"Ensemble Recall: {ensemble_recall}")
print(f"Ensemble F1 Score: {ensemble_f1}")
# Out:
# Ensemble Accuracy: 0.9758551307847082
# Ensemble Precision: 0.9550561797752809
# Ensemble Recall: 1.0
# Ensemble F1 Score: 0.9770114942528736

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate and print precision, recall, and F1 score
ensemble_accuracy = accuracy_score(Y_true, ensemble_predictions)
ensemble_precision = precision_score(Y_true, ensemble_predictions)
ensemble_recall = recall_score(Y_true, ensemble_predictions)
ensemble_f1 = f1_score(Y_true, ensemble_predictions)

print(f"Ensemble Accuracy: {ensemble_accuracy}")
print(f"Ensemble Precision: {ensemble_precision}")
print(f"Ensemble Recall: {ensemble_recall}")
print(f"Ensemble F1 Score: {ensemble_f1}")

# Results
metrics_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
metrics_values = [ensemble_accuracy, ensemble_precision, ensemble_recall, ensemble_f1]

# Bar plot
plt.figure(figsize=(8, 5))
bars = plt.bar(metrics_names, metrics_values, color=['blue', 'green', 'orange', 'red'])
plt.ylim(0, 1)  # Set the y-axis limit to be between 0 and 1 for better visualization
plt.title('Ensemble Model Metrics')
plt.ylabel('Score')


# Function to add value labels on top of the bars
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        plt.text(rect.get_x() + rect.get_width()/2., height,
                 f'{height:.2f}', ha='center', va='bottom')

# Call the function to add labels
autolabel(bars)

plt.show()
# Out:
# Ensemble Accuracy: 0.9758551307847082
# Ensemble Precision: 0.9550561797752809
# Ensemble Recall: 1.0
# Ensemble F1 Score: 0.9770114942528736

# %%
# Calculate and print precision, recall, and F1 score
ensemble_accuracy = accuracy_score(Y_true, ensemble_predictions)
ensemble_precision = precision_score(Y_true, ensemble_predictions)
ensemble_recall = recall_score(Y_true, ensemble_predictions)
ensemble_f1 = f1_score(Y_true, ensemble_predictions)

print(f"Ensemble Accuracy: {ensemble_accuracy}")
print(f"Ensemble Precision: {ensemble_precision}")
print(f"Ensemble Recall: {ensemble_recall}")
print(f"Ensemble F1 Score: {ensemble_f1}")

# Create a bar chart for precision, recall, and F1 score
metrics = ['Accuracy','Precision', 'Recall', 'F1 Score']
values = [ensemble_accuracy,ensemble_precision, ensemble_recall, ensemble_f1]

plt.figure(figsize=(10, 6))
plt.plot(metrics, values, marker='o', linestyle='-', color='b')
plt.title('Ensemble Model Metrics')
plt.xlabel('Metrics')
plt.ylabel('Values')

# Annotate the points with their values
for metric, value in zip(metrics, values):
    plt.text(metric, value, f'{value:.2f}', ha='center', va='bottom')

plt.show()
# Out:
# Ensemble Accuracy: 0.9758551307847082
# Ensemble Precision: 0.9550561797752809
# Ensemble Recall: 1.0
# Ensemble F1 Score: 0.9770114942528736

# %%
Seed = 40

train = train.sample(frac = 1, replace=False, random_state = Seed)

# Reset indices (row numbers)
train = train.reset_index(drop = True)

sns.countplot(x = "ID", data = train).set_title("Frequency Histogram (0: COVID, 1:Non-COVID)")
train
# Out:
#                                 File  ID Disease Type
# 0              COVID/Covid (246).png   0        COVID
# 1              COVID/Covid (488).png   0        COVID
# 2     non-COVID/Non-Covid (1076).png   1    non-COVID
# 3      non-COVID/Non-Covid (195).png   1    non-COVID
# 4      non-COVID/Non-Covid (483).png   1    non-COVID
# ...                              ...  ..          ...
# 2476   non-COVID/Non-Covid (708).png   1    non-COVID
# 2477    non-COVID/Non-Covid (72).png   1    non-COVID
# 2478   non-COVID/Non-Covid (127).png   1    non-COVID
# 2479  non-COVID/Non-Covid (1057).png   1    non-COVID
# 2480   non-COVID/Non-Covid (645).png   1    non-COVID
#
# [2481 rows x 3 columns]

# %%
def plot_defects(defect_types, rows, cols):
    fig, ax = plt.subplots(rows, cols, figsize=(12, 12))
    defect_files = train['File'][train['Disease Type'] == defect_types].values
    
    n = 0
    fig.suptitle(defect_types, fontsize = 22, color = "white")
    for i in range(rows):
        for j in range(cols):
            image_path = os.path.join(data_dir, defect_files[n])
            ax[i, j].set_xticks([])
            ax[i, j].set_yticks([])
            ax[i, j].imshow(cv2.imread(image_path))
            n += 1


plot_defects('COVID', 3, 3)
plot_defects('non-COVID', 3, 3)
